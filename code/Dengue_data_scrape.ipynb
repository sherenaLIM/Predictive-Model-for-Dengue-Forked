# %% [markdown]
# ## Scraping Latest Dengue Data

# %%
import requests
import selenium as sm
from bs4 import BeautifulSoup
from onemapsg import OneMapClient

import geopandas as gpd
import pandas as pd
import numpy as np
import json

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Installation of Packages

# %%
### Please install onemapsg package in order to run the codes below ###
# !pip install onemapsg

# documentation here: https://pypi.org/project/onemapsg/

# %%
### You will need an OneMap API account ###
# access token created 27 Mar 2023
# eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..4E_ntNYK3NMDqsuYvzjqFNAJOx_aJkDFEUYLyPky0eQ

# %% [markdown]
# ### OneMap API Setup

# %%
# call OneMap API
OM_client = OneMapClient("fishenterprise@gmail.com", "GA-dsi-sg-9-2023")

# %%
# get themes data
OM_client.get_all_themes_info(more_info=False)
# Out:
# REFRESHING TOKEN. NEW EXPIRY: 1680170937
# {'Theme_Names': [{'THEMENAME': 'MCE KPE Speed Camera',
#    'QUERYNAME': 'mce_kpe_speed_camera',
#    'ICON': 'icon_enforcementCam_20-01.jpg'},
#   {'THEMENAME': 'Singapore Police Force Mobile Speed Cameras',
#    'QUERYNAME': 'spf_msc',
#    'ICON': 'SpeedCam_logo.gif'},
#   {'THEMENAME': 'Liquor Control Zone(s) proclaimed under Liquor Control (Supply and Consumption) Act 2015',
#    'QUERYNAME': 'liquor_control_zones',
#    'ICON': 'Crest_20x20.jpg'},
#   {'THEMENAME': 'Singapore Police Force - 32nd ASEAN Summit Istana Special Zone',
#    'QUERYNAME': 'as_istana_core',
#    'ICON': 'Crest_20x20.jpg'},
#   {'THEMENAME': 'Singapore Police Force - 32nd ASEAN Summit Istana Special Event Area',
#    'QUERYNAME': 'as_istana_buffer',
#    'ICON': 'Crest_20x20.jpg'},
#   {'THEMENAME': 'Inland Ash Scattering Gardens',
#    'QUERYNAME': 'ias',
#    'ICON': 'circle.png'},
#   {'THEMENAME': 'CET Centres', 'QUERYNAME': 'cetcentres', 'ICON': 'WSQ.jpg'},
#   {'THEMENAME': 'HDB Branches',
#    'QUERYNAME': 'hdb_branches',
#    'ICON': 'M0906.png'},
#   {'THEMENAME': 'Licensed premises for petroleum products',
#    'QUERYNAME': 'customs_petroleum_product',
#    'ICON': 'null'},
#   {'THEMENAME': 'NParks BBQ Pits',
#    'QUERYNAME': 'nparks_bbq_pit',
#    'ICON': 'null'},
#   {'THEMENAME': 'PA Headquarters',
#    'QUERYNAME': 'paheadquarters',
#    'ICON': 'PA.jpg'},
#   {'THEMENAME': 'Breast Screening Centre',
#    'QUERYNAME': 'breastscreen',
#    'ICON': 'breastscreen.jpg'},
#   {'THEMENAME': 'Eldercare Services',
#    'QUERYNAME': 'eldercare',
#    'ICON': 'onemap-fc-eldercare.png'},
#   {'THEMENAME': 'Fire Posts', 'QUERYNAME': 'firepost', 'ICON': 'FP.png'},
#   {'THEMENAME': 'Funeral Parlours',
#    'QUERYNAME': 'funeralparlours',
#    'ICON': 'circle.png'},
#   {'THEMENAME': 'Water Ventures',
#    'QUERYNAME': 'waterventure',
#    'ICON': 'Water-Venture.gif'},
#   {'THEMENAME': 'Estate Upgrading Programme (EUP) Works for OSP',
#    'QUERYNAME': 'bca_estate_upg_prog_osp',
#    'ICON': 'null'},
#   {'THEMENAME': 'JTC Business Park Land',
#    'QUERYNAME': 'jtc_luse_bp_bpw',
#    'ICON': 'null'},
#   {'THEMENAME': 'SAFRA Centres',
#    'QUERYNAME': 'hsgb_safra',
#    'ICON': 'SAFRA.png'},
#   {'THEMENAME': 'Hawker Centres',
#    'QUERYNAME': 'hawkercentre',
#    'ICON': 'HC icons_Opt 8.jpg'},
#   {'THEMENAME': 'Hotels', 'QUERYNAME': 'hotels', 'ICON': 'hotel.gif'},
#   {'THEMENAME': 'Singapore Police Force Establishments (2018)',
#    'QUERYNAME': 'spf_establishments_2018',
#    'ICON': 'Crest_20x20.jpg'},
#   {'THEMENAME': 'ABC Waters Sites',
#    'QUERYNAME': 'abcwaterssites',
#    'ICON': 'abclogo_onemap.png'},
#   {'THEMENAME': 'Road Speed Limit',
#    'QUERYNAME': 'roadattributeline_speedlimits',
#    'ICON': 'null'},
#   {'THEMENAME': 'Healthier Hawker Centres',
#    'QUERYNAME': 'healthier_hawker_centres',
#    'ICON': 'HCS logo.jpg'},
#   {'THEMENAME': 'LTA & Town Council Cycling Paths',
#    'QUERYNAME': 'lta_cycling_paths',
#    'ICON': 'cycling.jpg'},
#   {'THEMENAME': 'IP Service Providers',
#    'QUERYNAME': 'ip_serviceproviders',
#    'ICON': 'ipServiceLogo.jpg'},
#   {'THEMENAME': 'PA Holiday Facilities',
#    'QUERYNAME': 'otherfacilities',
#    'ICON': 'PA.jpg'},
#   {'THEMENAME': 'NEA Offices',
#    'QUERYNAME': 'neaoffices',
#    'ICON': 'ecoa20.jpg'},
#   {'THEMENAME': 'SCDF HQs and Training Establishments',
#    'QUERYNAME': 'scdfhq',
#    'ICON': 'SCDF.jpg'},
#   {'THEMENAME': 'Cleaning Sectors',
#    'QUERYNAME': 'cleansing_outsourced',
#    'ICON': 'cleansing sector.jpg'},
#   {'THEMENAME': 'Disability Services',
#    'QUERYNAME': 'disability',
#    'ICON': 'onemap-fc-disability.png'},
#   {'THEMENAME': 'Fitness and Conditioning Centres (FCC)',
#    'QUERYNAME': 'hsgb_fcc',
#    'ICON': 'HSGB_FCC.png'},
#   {'THEMENAME': 'Fire Stations', 'QUERYNAME': 'firestation', 'ICON': 'FS.PNG'},
#   {'THEMENAME': 'Quit Centres',
#    'QUERYNAME': 'quitcentres',
#    'ICON': 'quitcentres.jpg'},
#   {'THEMENAME': 'Social Service Offices',
#    'QUERYNAME': 'sso',
#    'ICON': 'sso_20_px_by_20_px.jpg'},
#   {'THEMENAME': 'Licensed Premises for Liquors & Tabacco Products',
#    'QUERYNAME': 'customs_tabacco_product',
#    'ICON': 'null'},
#   {'THEMENAME': 'NAPFA Test Centre',
#    'QUERYNAME': 'hsgb_napfa',
#    'ICON': 'HSGB_FCC.png'},
#   {'THEMENAME': 'SportSG Sport Facilities',
#    'QUERYNAME': 'sportsg_sport_facilities',
#    'ICON': 'RedDot(20x20px)clear.png'},
#   {'THEMENAME': 'TradeNet Service Centres & Certified Vendors',
#    'QUERYNAME': 'customs_tradenet_service',
#    'ICON': 'null'},
#   {'THEMENAME': 'Tree Conservation Area',
#    'QUERYNAME': 'tree_conservation_area',
#    'ICON': 'null'},
#   {'THEMENAME': 'URA Project (PUBLIC)',
#    'QUERYNAME': 'ura_project_public_pl',
#    'ICON': 'null'},
#   {'THEMENAME': 'Liquor Control Zone under Public Order (Additional Temporary Measures) Act 2014',
#    'QUERYNAME': 'liquor_control_zone',
#    'ICON': 'null'},
#   {'THEMENAME': 'Monuments', 'QUERYNAME': 'monuments', 'ICON': 'heritage.gif'},
#   {'THEMENAME': 'Museums', 'QUERYNAME': 'museum', 'ICON': 'mr.gif'},
#   {'THEMENAME': 'Locations of Remittance',
#    'QUERYNAME': 'remittance',
#    'ICON': 'onemap_Remittance_20.png'},
#   {'THEMENAME': 'Areas within Restricted Areas',
#    'QUERYNAME': 'restricted_areaspoly',
#    'ICON': 'CAAS.JPG'},
#   {'THEMENAME': 'Silver Infocomm',
#    'QUERYNAME': 'silverinfocomm',
#    'ICON': 'silverInfocomm.png'},
#   {'THEMENAME': 'LTA Bicycle Rack',
#    'QUERYNAME': 'bicyclerack',
#    'ICON': 'Bikepark.jpg'},
#   {'THEMENAME': 'Singapore Police Force - 32nd ASEAN Summit Shangri-La Hotel Special Zone',
#    'QUERYNAME': 'as_shangrila_core',
#    'ICON': 'Crest_20x20.jpg'},
#   {'THEMENAME': 'Singapore Police Force - 32nd ASEAN Summit Shangri-La Hotel Special Event Area',
#    'QUERYNAME': 'as_shangrila_buffer',
#    'ICON': 'Crest_20x20.jpg'},
#   {'THEMENAME': 'Aedes Mosquito Breeding Habitats - South East',
#    'QUERYNAME': 'breedinghabitat_southeast_area',
#    'ICON': 'Picture1.png'},
#   {'THEMENAME': 'Aedes Mosquito Breeding Habitats - Central',
#    'QUERYNAME': 'breedinghabitat_central_area',
#    'ICON': 'Picture1.png'},
#   {'THEMENAME': 'Civil Defence Public Shelters',
#    'QUERYNAME': 'civildefencepublicshelters',
#    'ICON': 'Onemap.png'},
#   {'THEMENAME': 'Electoral Boundary 2006',
#    'QUERYNAME': 'ed_bdy_2009',
#    'ICON': 'null'},
#   {'THEMENAME': 'Electoral Boundary 2011',
#    'QUERYNAME': 'tb_msis_gaz_ed',
#    'ICON': 'null'},
#   {'THEMENAME': 'Singapore Coastal Habitats Map from High Resolution Satellite Imagery (2010/2011)',
#    'QUERYNAME': 'singapore_cmhabitats_20102011',
#    'ICON': 'null'},
#   {'THEMENAME': 'Certificate Grading Info of Licensed Eating Establishments',
#    'QUERYNAME': 'track_record_ils_feb18',
#    'ICON': 'icon.png'},
#   {'THEMENAME': 'CAAS Zones for Solar PV Consultation',
#    'QUERYNAME': 'solarpv_zones',
#    'ICON': 'CAAS logo.png'},
#   {'THEMENAME': 'Active Cemeteries',
#    'QUERYNAME': 'activecemeteries',
#    'ICON': 'circle.png'},
#   {'THEMENAME': 'Crematoria', 'QUERYNAME': 'crematoria', 'ICON': 'circle.png'},
#   {'THEMENAME': 'Dedicated Columbaria',
#    'QUERYNAME': 'columbaria',
#    'ICON': 'circle.png'},
#   {'THEMENAME': 'RecycleNSave Reverse Vending Machines (RVMs) Locations',
#    'QUERYNAME': 'rvm',
#    'ICON': 'RVMresized2.png'},
#   {'THEMENAME': 'Strengthening Families Programme',
#    'QUERYNAME': 'strengtheningfam',
#    'ICON': '1map.jpg'},
#   {'THEMENAME': 'Singapore Police Force - National Day Parade 2022 Special Event Area',
#    'QUERYNAME': 'geospace_ndp_22_sea_modified',
#    'ICON': 'null'},
#   {'THEMENAME': 'Singapore Police Force - National Day Parade 2022 Special Zone',
#    'QUERYNAME': 'geospace_ndp22_sz',
#    'ICON': 'null'},
#   {'THEMENAME': 'Singapore Police Force - National Day Parade (NDP) 2022 Special Event Area',
#    'QUERYNAME': 'ndp_22_sea',
#    'ICON': 'spf_icon.jpg'},
#   {'THEMENAME': 'Singapore Police Force - National Day Parade (NDP) 2022 Special Zone',
#    'QUERYNAME': 'ndp_22_sz',
#    'ICON': 'spf_icon.jpg'},
#   {'THEMENAME': 'Centralised Grasscutting Area',
#    'QUERYNAME': 'central_grasscutting',
#    'ICON': 'untitled.png'},
#   {'THEMENAME': 'AXS QuickBill',
#    'QUERYNAME': 'axs_quickbill',
#    'ICON': 'redQB.png'},
#   {'THEMENAME': 'Skyrise Greenery',
#    'QUERYNAME': 'skyrisegreenery',
#    'ICON': 'circle.png'},
#   {'THEMENAME': 'SportSG Sport Facilities',
#    'QUERYNAME': 'ssc_sports_facilities',
#    'ICON': 'RedDot(20x20px)clear.png'},
#   {'THEMENAME': 'Tourist Attractions',
#    'QUERYNAME': 'tourism',
#    'ICON': 'tourist_spot.gif'},
#   {'THEMENAME': 'Waste Disposal Site',
#    'QUERYNAME': 'wastedisposalsite',
#    'ICON': 'disposala20.png'},
#   {'THEMENAME': 'Wireless HotSpots',
#    'QUERYNAME': 'wireless_hotspots',
#    'ICON': 'wireless.gif'},
#   {'THEMENAME': 'Community Mediation',
#    'QUERYNAME': 'commmediationctr',
#    'ICON': 'null'},
#   {'THEMENAME': 'Drainage Construction',
#    'QUERYNAME': 'drainageconstruction',
#    'ICON': 'null'},
#   {'THEMENAME': 'Licensed Premises for Motor Vehicles',
#    'QUERYNAME': 'customs_motor_vehicle',
#    'ICON': 'null'},
#   {'THEMENAME': 'URA Parking Lot',
#    'QUERYNAME': 'ura_parking_lot',
#    'ICON': 'ParkingLot.png'},
#   {'THEMENAME': 'CPF Service Centres',
#    'QUERYNAME': 'cpfb_location',
#    'ICON': 'logocpf.png'},
#   {'THEMENAME': 'After Death Facilities',
#    'QUERYNAME': 'afterdeathfacilities',
#    'ICON': 'coffina20.jpg'},
#   {'THEMENAME': 'CareersConnect',
#    'QUERYNAME': 'wdaservicepoints',
#    'ICON': 'WSQ.jpg'},
#   {'THEMENAME': 'Bloodbank locations',
#    'QUERYNAME': 'blood_bank',
#    'ICON': 'iconbloodbank_new.jpg'},
#   {'THEMENAME': 'Healthier Caterers',
#    'QUERYNAME': 'healthiercaterers',
#    'ICON': 'HCS.jpg'},
#   {'THEMENAME': 'Healthier Eateries',
#    'QUERYNAME': 'healthierdining',
#    'ICON': 'HealthierDining.PNG'},
#   {'THEMENAME': 'Waste Treatment',
#    'QUERYNAME': 'wastetreatment',
#    'ICON': 'skull2a20.png'},
#   {'THEMENAME': 'Maxwell Chambers F&B map',
#    'QUERYNAME': 'maxwell_fnb_map',
#    'ICON': 'null'},
#   {'THEMENAME': 'Private Education Institutions',
#    'QUERYNAME': 'cpe_pei_premises',
#    'ICON': 'pink.jpg'},
#   {'THEMENAME': 'Singapore Police Force Fixed Speed Cameras',
#    'QUERYNAME': 'spf_fsc',
#    'ICON': 'SpeedCam_logo.gif'},
#   {'THEMENAME': 'SewerageConstruction',
#    'QUERYNAME': 'sewerageconstruction',
#    'ICON': 'null'},
#   {'THEMENAME': 'Community Devt Councils',
#    'QUERYNAME': 'cdcouncils',
#    'ICON': 'PA.jpg'},
#   {'THEMENAME': 'Areas within Danger Areas',
#    'QUERYNAME': 'danger_areas',
#    'ICON': 'CAAS logo.png'},
#   {'THEMENAME': 'Infocomm Accessibility',
#    'QUERYNAME': 'infocommaccess',
#    'ICON': 'ico_mouse.gif'},
#   {'THEMENAME': 'Other PA Networks',
#    'QUERYNAME': 'otherpanetworks',
#    'ICON': 'PA.jpg'},
#   {'THEMENAME': 'Areas within Prohibited Areas',
#    'QUERYNAME': 'prohibited_areas',
#    'ICON': 'CAAS logo.png'},
#   {'THEMENAME': 'WaterActivities@SG',
#    'QUERYNAME': 'aquaticsg',
#    'ICON': 'aquaticsg.png'},
#   {'THEMENAME': 'Stables', 'QUERYNAME': 'stables', 'ICON': 'stableslogo.PNG'},
#   {'THEMENAME': 'Nature Reserves Gazette 2005',
#    'QUERYNAME': 'nr_gaz_2005',
#    'ICON': 'gazette.jpg'},
#   {'THEMENAME': 'Designated Smoking Areas',
#    'QUERYNAME': 'dsa',
#    'ICON': 'icon.png'},
#   {'THEMENAME': 'Certificate Grading Info of Licensed Eating Establishments',
#    'QUERYNAME': 'track_record_ils_feb18',
#    'ICON': 'icon.png'},
#   {'THEMENAME': 'HDB Existing Building',
#    'QUERYNAME': 'hdb_active_blk_p',
#    'ICON': 'null'},
#   {'THEMENAME': 'DUS Schools Sports Facilities',
#    'QUERYNAME': 'dus_school_sports_facilities',
#    'ICON': 'RedDot(20x20px)clear.png'},
#   {'THEMENAME': 'ISP Clinics',
#    'QUERYNAME': 'moh_isp_clinics',
#    'ICON': 'OM2_MOHicon_ISPClinic_20px.png'},
#   {'THEMENAME': 'Heritage Trees',
#    'QUERYNAME': 'heritagetrees',
#    'ICON': 'tree_icon_supercompressed.jpg'},
#   {'THEMENAME': 'HDB Neighbourhood Renewal Programme Proposed and Under-Construction (NRP)',
#    'QUERYNAME': 'hdbnrpunderconstruction',
#    'ICON': 'null'},
#   {'THEMENAME': 'NParks Activity Area',
#    'QUERYNAME': 'nparks_activity_area',
#    'ICON': 'null'},
#   {'THEMENAME': 'Family Services',
#    'QUERYNAME': 'family',
#    'ICON': 'onemap-fc-family.png'},
#   {'THEMENAME': 'Gyms@SG',
#    'QUERYNAME': 'exercisefacilities',
#    'ICON': 'Fit@SG.png'},
#   {'THEMENAME': 'Student Care Services',
#    'QUERYNAME': 'studentcare',
#    'ICON': 'onemap-fc-studentcare.png'},
#   {'THEMENAME': 'LTA Road Camera',
#    'QUERYNAME': 'lta_road_enforcement_camera',
#    'ICON': 'icon_enforcementCam_20-01.jpg'},
#   {'THEMENAME': 'PUB Water Level Sensors',
#    'QUERYNAME': 'pub_waterlevelsensors',
#    'ICON': 'Capture.PNG'},
#   {'THEMENAME': 'Constituency Offices',
#    'QUERYNAME': 'constituencyoffices',
#    'ICON': 'PA.jpg'},
#   {'THEMENAME': 'Locations of Money Changer',
#    'QUERYNAME': 'moneychanger',
#    'ICON': 'onemap_MoneyExchange_20.png'},
#   {'THEMENAME': 'Protected Area under Section 7 Air Navigation Act',
#    'QUERYNAME': 'mha_uav_2015',
#    'ICON': 'MHA-Logo 20-20.png'},
#   {'THEMENAME': 'SportsFields@SG',
#    'QUERYNAME': 'playsg',
#    'ICON': 'playsg.png'},
#   {'THEMENAME': 'Under-Construction Parks',
#    'QUERYNAME': 'nparks_uc_parks',
#    'ICON': 'null'},
#   {'THEMENAME': 'E-waste Recycling_NEW',
#    'QUERYNAME': 'ewaste_new',
#    'ICON': 'ewaste.jpg'},
#   {'THEMENAME': 'Singapore Police Force - PCG Offshore Islands',
#    'QUERYNAME': 'pcg_offshore_islands',
#    'ICON': 'Crest_20x20.jpg'},
#   {'THEMENAME': 'Prohibited Drone flying areas at NParks Nature Reserves, Nature Parks and Gardens',
#    'QUERYNAME': 'drone_no_fly',
#    'ICON': 'LOGGGGGG.jpg'},
#   {'THEMENAME': 'Dementia Friendly Go-To-Points (GTPs)',
#    'QUERYNAME': 'dfc_gtp',
#    'ICON': 'Go To Point Logo 19x18.png'},
#   {'THEMENAME': 'Under-Construction Park Facilities',
#    'QUERYNAME': 'underconstruction_facilities',
#    'ICON': 'null'},
#   {'THEMENAME': 'HDB Car Park Information',
#    'QUERYNAME': 'hdb_car_park_information',
#    'ICON': 'map-carpark.jpg'},
#   {'THEMENAME': 'Industrial Government Land Sales - Sites',
#    'QUERYNAME': 'igls_sites',
#    'ICON': 'null'},
#   {'THEMENAME': 'ABC Waters Construction',
#    'QUERYNAME': 'abcwatersconstruction',
#    'ICON': 'tender-map-abc.png'},
#   {'THEMENAME': 'Cervical Screening Centre',
#    'QUERYNAME': 'cervicalscreen',
#    'ICON': 'CSS.jpg'},
#   {'THEMENAME': 'Retail pharmacy locations',
#    'QUERYNAME': 'registered_pharmacy',
#    'ICON': 'Pharmacies_new.jpg'},
#   {'THEMENAME': 'NParks Skyrise Greenery',
#    'QUERYNAME': 'skyrise_greenery',
#    'ICON': 'npark.png'},
#   {'THEMENAME': 'Community Clubs',
#    'QUERYNAME': 'communityclubs',
#    'ICON': 'PA.jpg'},
#   {'THEMENAME': 'Heritage Road Green Buffers',
#    'QUERYNAME': 'heritageroadgreenbuffer',
#    'ICON': 'null'},
#   {'THEMENAME': 'JTC Temporary Occupation License',
#    'QUERYNAME': 'jtc_tol',
#    'ICON': 'null'},
#   {'THEMENAME': 'LTA Rail Project Under Construction (Unclassified)',
#    'QUERYNAME': 'ltarailprj_uc_unclass',
#    'ICON': 'null'},
#   {'THEMENAME': 'PCN Access Points',
#    'QUERYNAME': 'pcn_access_points',
#    'ICON': 'icon36x36pcn.jpg'},
#   {'THEMENAME': 'WaterSupplyConstruction',
#    'QUERYNAME': 'watersupplyconstruction',
#    'ICON': 'null'},
#   {'THEMENAME': 'Community in Bloom (CIB)',
#    'QUERYNAME': 'cib_gardens',
#    'ICON': 'Resized-BHFPC.jpg'},
#   {'THEMENAME': 'Parks', 'QUERYNAME': 'nationalparks', 'ICON': 'parks.gif'},
#   {'THEMENAME': 'Park Connector Loop',
#    'QUERYNAME': 'park_connector_loop',
#    'ICON': 'image.jpg'},
#   {'THEMENAME': 'Pre-Schools Location',
#    'QUERYNAME': 'preschools_location',
#    'ICON': 'location-icon.png'},
#   {'THEMENAME': 'Licensed Premises for Zero GST Goods',
#    'QUERYNAME': 'customs_zero_gst_goods',
#    'ICON': 'null'},
#   {'THEMENAME': 'Aedes Mosquito Breeding Habitats - North West',
#    'QUERYNAME': 'breedinghabitat_northwest_area',
#    'ICON': 'Picture1.png'},
#   {'THEMENAME': 'Electoral Boundary 2015',
#    'QUERYNAME': 'eld2015',
#    'ICON': 'null'},
#   {'THEMENAME': 'No Smoking Zones', 'QUERYNAME': 'nsz', 'ICON': 'icon.png'},
#   {'THEMENAME': 'HDB Cycling Paths Under-Construction',
#    'QUERYNAME': 'hdbcyclingunderconstruction',
#    'ICON': 'null'},
#   {'THEMENAME': 'Community Led Areas',
#    'QUERYNAME': 'community_led_areas',
#    'ICON': 'CAAS logo.png'},
#   {'THEMENAME': 'Open Use Areas',
#    'QUERYNAME': 'open_use_areas',
#    'ICON': 'CAAS logo.png'},
#   {'THEMENAME': 'Dengue (Cases) - North West',
#    'QUERYNAME': 'denguecase_northwest_area',
#    'ICON': 'Picture1.png'},
#   {'THEMENAME': 'Bomb shelters', 'QUERYNAME': 'bombshelters', 'ICON': 'null'},
#   {'THEMENAME': 'Under-Construction Park Connectors',
#    'QUERYNAME': 'nparks_uc_pc',
#    'ICON': 'null'},
#   {'THEMENAME': 'NParks Lamp Post',
#    'QUERYNAME': 'nparks_lamppost',
#    'ICON': 'untitled2.png'},
#   {'THEMENAME': 'Areas within 5km of aerodromes',
#    'QUERYNAME': 'boundary_5km',
#    'ICON': 'CAAS logo.png'},
#   {'THEMENAME': 'NParks Parks and Nature Reserves',
#    'QUERYNAME': 'nparks_parks',
#    'ICON': 'image.gif'},
#   {'THEMENAME': 'Singapore Police Force Establishments',
#    'QUERYNAME': 'spf_establishments',
#    'ICON': 'Crest_20x20.jpg'},
#   {'THEMENAME': 'E-waste Recycling',
#    'QUERYNAME': 'ewaste',
#    'ICON': 'ewaste.jpg'},
#   {'THEMENAME': 'Parks@SG', 'QUERYNAME': 'relaxsg', 'ICON': 'relaxsg.png'},
#   {'THEMENAME': 'HDB Public Housing Building Under-Construction',
#    'QUERYNAME': 'hdbbuildingunderconstruction',
#    'ICON': 'null'},
#   {'THEMENAME': 'HDB Lift Upgrading Programme Proposed and Under-Construction (LUP)',
#    'QUERYNAME': 'hdbluppropunderconstruction',
#    'ICON': 'null'},
#   {'THEMENAME': 'IPPT In Your Community',
#    'QUERYNAME': 'hsgb_ippt',
#    'ICON': 'HSGB_FCC.png'},
#   {'THEMENAME': 'JTC Estate Name Boundary',
#    'QUERYNAME': 'jtc_estate_name',
#    'ICON': 'null'},
#   {'THEMENAME': 'LTA Parking Standards Zone',
#    'QUERYNAME': 'parkingstandardszone',
#    'ICON': 'psz-LOGO_20by20.png'},
#   {'THEMENAME': 'Singapore Police Force Red Light Cameras',
#    'QUERYNAME': 'spf_rlc',
#    'ICON': 'SpeedCam_logo.gif'},
#   {'THEMENAME': 'Singapore Police Force Police Speed Laser Cameras',
#    'QUERYNAME': 'spf_pslc',
#    'ICON': 'SpeedCam_logo.gif'},
#   {'THEMENAME': 'Singapore Police Force Digital Traffic Red Light Cameras',
#    'QUERYNAME': 'spf_dtrls',
#    'ICON': 'DTRLS--logo.gif'},
#   {'THEMENAME': 'Community Use Sites',
#    'QUERYNAME': 'comm_use_sites',
#    'ICON': 'recreation_sla.gif'},
#   {'THEMENAME': 'Historic Sites',
#    'QUERYNAME': 'historicsites',
#    'ICON': 'onemapicon.gif'},
#   {'THEMENAME': 'Kindergartens',
#    'QUERYNAME': 'kindergartens',
#    'ICON': 'school.gif'},
#   {'THEMENAME': 'Libraries', 'QUERYNAME': 'libraries', 'ICON': 'library.gif'},
#   {'THEMENAME': "Residents' Committee / Residents' Network Centre",
#    'QUERYNAME': 'residentscommittee',
#    'ICON': 'RC_20.gif'},
#   {'THEMENAME': 'Aedes Mosquito Breeding Habitats - South West',
#    'QUERYNAME': 'breedinghabitat_southwest_area',
#    'ICON': 'Picture1.png'},
#   {'THEMENAME': 'Aedes Mosquito Breeding Habitats - North East',
#    'QUERYNAME': 'breedinghabitat_northeast_area',
#    'ICON': 'Picture1.png'},
#   {'THEMENAME': 'Hawker Centres_New',
#    'QUERYNAME': 'hawkercentre_new',
#    'ICON': 'ONEMAPicon.png'},
#   {'THEMENAME': 'Dengue (Cases) - South East',
#    'QUERYNAME': 'denguecase_southeast_area',
#    'ICON': 'Picture1.png'},
#   {'THEMENAME': 'Dengue (Cases) - South West',
#    'QUERYNAME': 'denguecase_southwest_area',
#    'ICON': 'Picture1.png'},
#   {'THEMENAME': 'Community Club / PAssion WaVe Outlet',
#    'QUERYNAME': 'communityclubpassionwave',
#    'ICON': 'PA.jpg'},
#   {'THEMENAME': 'Channels for Donation, Resale and Repair',
#    'QUERYNAME': 'reusechannels',
#    'ICON': 'icon.png'},
#   {'THEMENAME': 'ABC Waters Completed',
#    'QUERYNAME': 'abcwaterscompleted',
#    'ICON': 'abclogo_onemap.png'},
#   {'THEMENAME': 'NParks Buildings',
#    'QUERYNAME': 'nparks_building',
#    'ICON': 'null'},
#   {'THEMENAME': 'Park Facilities',
#    'QUERYNAME': 'nparks_facilities',
#    'ICON': 'null'},
#   {'THEMENAME': 'NParks Car Park Lots',
#    'QUERYNAME': 'nparks_carpark_lots',
#    'ICON': 'null'},
#   {'THEMENAME': 'Singapore Police Force NPC Boundary',
#    'QUERYNAME': 'npc_boundary',
#    'ICON': 'Crest_20x20.jpg'},
#   {'THEMENAME': 'Social Service Agencies',
#    'QUERYNAME': 'voluntarywelfareorgs',
#    'ICON': 'onemap-fc-vwo.png'},
#   {'THEMENAME': 'Child Care Services',
#    'QUERYNAME': 'childcare',
#    'ICON': 'onemap-fc-childcare.png'},
#   {'THEMENAME': 'HDB Roads Under Construction',
#    'QUERYNAME': 'hdbroadsunderconstruction',
#    'ICON': 'null'},
#   {'THEMENAME': 'NPARKS Play/Fitness Equipment',
#    'QUERYNAME': 'nparks_play_fitness_eq',
#    'ICON': 'null'},
#   {'THEMENAME': 'Cycling Path Network',
#    'QUERYNAME': 'cyclingpath',
#    'ICON': '2016-03-31-CYCLING LOGO-Blue.jpg'},
#   {'THEMENAME': 'Friendly Buildings',
#    'QUERYNAME': 'bfabuildings',
#    'ICON': 'ARS logo20.jpg'},
#   {'THEMENAME': 'Public Access AEDs',
#    'QUERYNAME': 'aed_locations',
#    'ICON': 'aedlogo.png'},
#   {'THEMENAME': 'LTA Road Construction Project (Unclassified)',
#    'QUERYNAME': 'lta_rdproj_unclass',
#    'ICON': 'null'},
#   {'THEMENAME': 'NParks Tracks', 'QUERYNAME': 'nparks_tracks', 'ICON': 'null'},
#   {'THEMENAME': 'Dengue (Cases) - North East',
#    'QUERYNAME': 'denguecase_northeast_area',
#    'ICON': 'Picture1.png'},
#   {'THEMENAME': 'Dengue Clusters',
#    'QUERYNAME': 'dengue_cluster',
#    'ICON': 'mosquitoa20.jpg'},
#   {'THEMENAME': 'Dengue (Cases) - Central',
#    'QUERYNAME': 'denguecase_central_area',
#    'ICON': 'Picture1.png'},
#   {'THEMENAME': 'Areas with High Aedes Population',
#    'QUERYNAME': 'areas_hap',
#    'ICON': 'mosquito.png'},
#   {'THEMENAME': 'SportSG DUS Sport Facilities',
#    'QUERYNAME': 'sportsg_dus_sport_facilities',
#    'ICON': '20170810_DUS_ICON.png'},
#   {'THEMENAME': 'Green Mark Buildings',
#    'QUERYNAME': 'greenbuilding',
#    'ICON': 'gml_j20.jpg'}]}

# %% [markdown]
# ### Functions

# %%
def get_datestamp(dic, fmt='%Y-%m-%d'):
    '''
    Function that gets the datestamp from the dictionary output scraped from OneMap
    
    Parameters:
    -----------
    dic: dictionary
        dictionary output from OneMap
        
    fmt: str
        format of datestamp
        Default = %Y-%m-%d
        
    Returns:
    --------
    str
        datestamp in format fmt
        
    '''
    
    import pandas as pd
    
    # check if dic is valid with SrchResults and DateTime keys
    try:
        # extract datestamp from dictionary
        datestamp = pd.to_datetime(dic['SrchResults'][0]['DateTime']['date'])
        # convert to SG time
        datestamp = datestamp - pd.DateOffset(hours=-8)
    except:
        print('Input is not a valid dictionary output from OneMap')
        return 
    
    # return the datestamp based on fmt format
    return datestamp.strftime(fmt)

# %%
def scrape_onemap_themes(client, theme):
    '''
    Function that scrapes the specified theme from OneMap
    
    Parameters:
    -----------
    client: onemapsg object
        OneMapClient object that has been instantiated
        
    theme: str or list
        theme(s) to be scraped
    
    Returns:
    --------
    dictionary
        dictionary output from OneMap
        if theme is a list, returns a dictionary of dictionaries
    
    '''
    
    from onemapsg import OneMapClient
    
    # create empty dictionary
    output = {}
    
    if (type(theme) is list):
        for item in theme:
            # check that requested theme(s) is available on OneMap
            if list(client.get_theme_info(item).keys())[0] == 'Theme_Names':
                # if theme name is valid, scrape output
                output[item] = client.retrieve_theme(item)
                print(f'Successfully scraped {item}')
            else: print(f'{item} is an invalid theme')
    else:
        # if theme is just a string, return just the scraped output after checking
        if list(client.get_theme_info(theme).keys())[0] == 'Theme_Names':
            output = client.retrieve_theme(theme)
            print(f'Successfully scraped {theme}')
        else: print(f'{theme} is an invalid theme')
    
    # return output
    return output

# %%
def save_onemap_themes(dic, theme, folder_path='../datasets'):
    '''
    Function that saves a dictionary of dictionary outputs from OneMap into individual json files with datestamps
    
    Parameters:
    -----------
    dic: dictionary
        either a single OneMap dictionary output or a dictionary of dictionary outputs
        
    theme: str or list
        theme(s) to be saved    
        
    folder_path: str
        location to save the files to
        
    Returns:
    --------
    Nil
    
    '''
    
    import json
    
    # check if it is dictionary of dictionaries or just a single OneMap output
    try:
        test = dic['SrchResults']
        datestamp = get_datestamp(dic)
        json.dump(dic, open(f'{folder_path}/{theme}_{datestamp}.json', 'w'))
        print(f'Successfully saved {theme}')
    except:
        for key, item in dic.items():
            datestamp = get_datestamp(item)
            json.dump(item, open(f'{folder_path}/{key}_{datestamp}.json', 'w'))
            print(f'Successfully saved {key}')
    
    return

# %% [markdown]
# ### Scraping

# %%
# define list of themes to scrape
themes = [
    'dengue_cluster',
    'denguecase_northeast_area',
    'denguecase_northwest_area',
    'denguecase_central_area',
    'denguecase_southeast_area',
    'denguecase_southwest_area',
    'breedinghabitat_northeast_area',
    'breedinghabitat_northwest_area',
    'breedinghabitat_central_area',
    'breedinghabitat_southeast_area',
    'breedinghabitat_southwest_area'
]

# %%
# %%time
test = scrape_onemap_themes(OM_client, themes)
save_onemap_themes(test, themes)
# Out:
# REFRESHING TOKEN. NEW EXPIRY: 1680170937
# Successfully scraped dengue_cluster
# Successfully scraped denguecase_northeast_area
# Successfully scraped denguecase_northwest_area
# Successfully scraped denguecase_central_area
# Successfully scraped denguecase_southeast_area
# Successfully scraped denguecase_southwest_area
# Successfully scraped breedinghabitat_northeast_area
# Successfully scraped breedinghabitat_northwest_area
# Successfully scraped breedinghabitat_central_area
# Successfully scraped breedinghabitat_southeast_area
# Successfully scraped breedinghabitat_southwest_area
# Successfully saved dengue_cluster
# Successfully saved denguecase_northeast_area
# Successfully saved denguecase_northwest_area
# Successfully saved denguecase_central_area
# Successfully saved denguecase_southeast_area
# Successfully saved denguecase_southwest_area
# Successfully saved breedinghabitat_northeast_area
# Successfully saved breedinghabitat_northwest_area
# Successfully saved breedinghabitat_central_area
# Successfully saved breedinghabitat_southeast_area
# Successfully saved breedinghabitat_southwest_area
# CPU times: total: 422 ms
# Wall time: 40min 26s
